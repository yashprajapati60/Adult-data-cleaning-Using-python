# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import numpy as np

# %%
adult=pd.read_csv(r"D:\ft\adult.csv")

# %%
adult
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %%
adult.columns=['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation', 'relationship','race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'income']

# %%
adult
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
adult.loc[32561]=[39,'State-gov',77516,'Bachelors',13,'Never-married','Adm-clerical','Not-in-family','White','Male',2174,0,40,'United-States','<=50K']

# %%
adult
# Out:
#        age          workclass  fnlwgt   education  education_num  \
# 0       50   Self-emp-not-inc   83311   Bachelors             13
# 1       38            Private  215646     HS-grad              9
# 2       53            Private  234721        11th              7
# 3       28            Private  338409   Bachelors             13
# 4       37            Private  284582     Masters             14
# ...    ...                ...     ...         ...            ...
# 32556   40            Private  154374     HS-grad              9
# 32557   58            Private  151910     HS-grad              9
# 32558   22            Private  201490     HS-grad              9
# 32559   52       Self-emp-inc  287927     HS-grad              9
# 32561   39          State-gov   77516   Bachelors             13
#
#             marital_status          occupation    relationship    race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
adult[adult["workclass"]==" ?"]
# Out:
#        age workclass  fnlwgt      education  education_num  \
# 26      54         ?  180211   Some-college             10
# 60      32         ?  293936        7th-8th              4
# 68      25         ?  200681   Some-college             10
# 76      67         ?  212759           10th              6
# 105     17         ?  304873           10th              6
# ...    ...       ...     ...            ...            ...
# 32529   35         ?  320084      Bachelors             13
# 32530   30         ?   33811      Bachelors             13
# 32538   71         ?  287372      Doctorate             16
# 32540   41         ?  202822        HS-grad              9
# 32541   72         ?  129912        HS-grad              9
#
#                marital_status occupation    relationship                 race  \
# 26         Married-civ-spouse          ?         Husband   Asian-Pac-Islander
# 60      Married-spouse-absent          ?   Not-in-family                White
# ...

# %%
# adult["workclass"]=adult["workclass"].rename({' ?':"jobless"},inplace=True)

# %%
# adult.rename({' ?':'jobless'},inplace=True)

# %%
adult["workclass"].unique()
# Out:
# array([' Self-emp-not-inc', ' Private', ' State-gov', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked', 'State-gov'], dtype=object)

# %%
adult["workclass"].replace([' ?'],['jobless'],inplace=True)

# %%
adult
# Out:
#        age          workclass  fnlwgt   education  education_num  \
# 0       50   Self-emp-not-inc   83311   Bachelors             13
# 1       38            Private  215646     HS-grad              9
# 2       53            Private  234721        11th              7
# 3       28            Private  338409   Bachelors             13
# 4       37            Private  284582     Masters             14
# ...    ...                ...     ...         ...            ...
# 32556   40            Private  154374     HS-grad              9
# 32557   58            Private  151910     HS-grad              9
# 32558   22            Private  201490     HS-grad              9
# 32559   52       Self-emp-inc  287927     HS-grad              9
# 32561   39          State-gov   77516   Bachelors             13
#
#             marital_status          occupation    relationship    race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
adult[adult["education_num"]=="0"]
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education_num, marital_status, occupation, relationship, race, sex, capital_gain, capital_loss, hours_per_week, native_country, income]
# Index: []

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enc=LabelEncoder()

# %%
adult["workclass"]=enc.fit_transform(adult["workclass"])

# %%
adult
# Out:
#        age  workclass  fnlwgt   education  education_num       marital_status  \
# 0       50          5   83311   Bachelors             13   Married-civ-spouse
# 1       38          3  215646     HS-grad              9             Divorced
# 2       53          3  234721        11th              7   Married-civ-spouse
# 3       28          3  338409   Bachelors             13   Married-civ-spouse
# 4       37          3  284582     Masters             14   Married-civ-spouse
# ...    ...        ...     ...         ...            ...                  ...
# 32556   40          3  154374     HS-grad              9   Married-civ-spouse
# 32557   58          3  151910     HS-grad              9              Widowed
# 32558   22          3  201490     HS-grad              9        Never-married
# 32559   52          4  287927     HS-grad              9   Married-civ-spouse
# 32561   39          8   77516   Bachelors             13        Never-married
#
# ...

# %%
adult["education"].replace(["Bachelors"],[" Bachelors"],inplace=True)

# %%
adult["education"].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
adult["education"]=enc.fit_transform(adult["education"])

# %%
adult["education"].astype(int)
# Out:
# 0         9
# 1        11
# 2         1
# 3         9
# 4        12
#          ..
# 32556    11
# 32557    11
# 32558    11
# 32559    11
# 32561     9
# Name: education, Length: 32561, dtype: int32

# %%
adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32561 entries, 0 to 32561
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  int32
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  int32
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int32(2), int64(6), object(7)
# memory usage: 3.7+ MB

# %%
adult["native_country"].replace([" ?"," United-States",' Hong'],["Foreign","United-States","Hongkong"],inplace=True)

# %%
adult["native_country"].unique()
# Out:
# array(['United-States', ' Cuba', ' Jamaica', ' India', 'Foreign',
#        ' Mexico', ' South', ' Puerto-Rico', ' Honduras', ' England',
#        ' Canada', ' Germany', ' Iran', ' Philippines', ' Italy',
#        ' Poland', ' Columbia', ' Cambodia', ' Thailand', ' Ecuador',
#        ' Laos', ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam',
#        'Hongkong', ' Ireland', ' Hungary', ' Holand-Netherlands'],
#       dtype=object)

# %%
adult["native_country"]=enc.fit_transform(adult["native_country"])

# %%
adult
# Out:
#        age  workclass  fnlwgt  education  education_num       marital_status  \
# 0       50          5   83311          9             13   Married-civ-spouse
# 1       38          3  215646         11              9             Divorced
# 2       53          3  234721          1              7   Married-civ-spouse
# 3       28          3  338409          9             13   Married-civ-spouse
# 4       37          3  284582         12             14   Married-civ-spouse
# ...    ...        ...     ...        ...            ...                  ...
# 32556   40          3  154374         11              9   Married-civ-spouse
# 32557   58          3  151910         11              9              Widowed
# 32558   22          3  201490         11              9        Never-married
# 32559   52          4  287927         11              9   Married-civ-spouse
# 32561   39          8   77516          9             13        Never-married
#
# ...

# %%
adult["occupation"].unique()
# Out:
# array([' Exec-managerial', ' Handlers-cleaners', ' Prof-specialty',
#        ' Other-service', ' Adm-clerical', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv', 'Adm-clerical'], dtype=object)

# %%
adult["occupation"].unique()
# Out:
# array([' Exec-managerial', ' Handlers-cleaners', ' Prof-specialty',
#        ' Other-service', ' Adm-clerical', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv', 'Adm-clerical'], dtype=object)

# %%
adult["occupation"].replace([" ?"],["None"],inplace=True)

# %%
adult["occupation"]=enc.fit_transform(adult["occupation"])

# %%
adult
# Out:
#        age  workclass  fnlwgt  education  education_num       marital_status  \
# 0       50          5   83311          9             13   Married-civ-spouse
# 1       38          3  215646         11              9             Divorced
# 2       53          3  234721          1              7   Married-civ-spouse
# 3       28          3  338409          9             13   Married-civ-spouse
# 4       37          3  284582         12             14   Married-civ-spouse
# ...    ...        ...     ...        ...            ...                  ...
# 32556   40          3  154374         11              9   Married-civ-spouse
# 32557   58          3  151910         11              9              Widowed
# 32558   22          3  201490         11              9        Never-married
# 32559   52          4  287927         11              9   Married-civ-spouse
# 32561   39          8   77516          9             13        Never-married
#
# ...

# %%
adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32561 entries, 0 to 32561
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  int32
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  int32
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  int32
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  int32
#  14  income          32561 non-null  object
# dtypes: int32(4), int64(6), object(5)
# memory usage: 3.5+ MB

# %%
# from sklearn.preprocessing import OrdinalEncoder

# %%
adult["sex"].replace([" Male","Male"],inplace=True)

# %%
adult["sex"]
# Out:
# 0           Male
# 1           Male
# 2           Male
# 3         Female
# 4         Female
#           ...
# 32556     Female
# 32557     Female
# 32558     Female
# 32559     Female
# 32561     Female
# Name: sex, Length: 32561, dtype: object

# %%
# enc1=OrdinalEncoder()

# %%
adult["sex"].replace([" Male"," Female"],[0,1],inplace=True)

# %%
adult
# Out:
#        age  workclass  fnlwgt  education  education_num       marital_status  \
# 0       50          5   83311          9             13   Married-civ-spouse
# 1       38          3  215646         11              9             Divorced
# 2       53          3  234721          1              7   Married-civ-spouse
# 3       28          3  338409          9             13   Married-civ-spouse
# 4       37          3  284582         12             14   Married-civ-spouse
# ...    ...        ...     ...        ...            ...                  ...
# 32556   40          3  154374         11              9   Married-civ-spouse
# 32557   58          3  151910         11              9              Widowed
# 32558   22          3  201490         11              9        Never-married
# 32559   52          4  287927         11              9   Married-civ-spouse
# 32561   39          8   77516          9             13        Never-married
#
# ...

# %%
adult["race"].unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other', 'White'], dtype=object)

# %%
adult["race"].replace([" White"],['White'],inplace=True)

# %%
adult
# Out:
#        age  workclass  fnlwgt  education  education_num       marital_status  \
# 0       50          5   83311          9             13   Married-civ-spouse
# 1       38          3  215646         11              9             Divorced
# 2       53          3  234721          1              7   Married-civ-spouse
# 3       28          3  338409          9             13   Married-civ-spouse
# 4       37          3  284582         12             14   Married-civ-spouse
# ...    ...        ...     ...        ...            ...                  ...
# 32556   40          3  154374         11              9   Married-civ-spouse
# 32557   58          3  151910         11              9              Widowed
# 32558   22          3  201490         11              9        Never-married
# 32559   52          4  287927         11              9   Married-civ-spouse
# 32561   39          8   77516          9             13        Never-married
#
# ...

# %%
adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32561 entries, 0 to 32561
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  int32
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  int32
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  int32
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  int64
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  int32
#  14  income          32561 non-null  object
# dtypes: int32(4), int64(7), object(4)
# memory usage: 3.5+ MB

# %%
adult
# Out:
#        age  workclass  fnlwgt  education  education_num       marital_status  \
# 0       50          5   83311          9             13   Married-civ-spouse
# 1       38          3  215646         11              9             Divorced
# 2       53          3  234721          1              7   Married-civ-spouse
# 3       28          3  338409          9             13   Married-civ-spouse
# 4       37          3  284582         12             14   Married-civ-spouse
# ...    ...        ...     ...        ...            ...                  ...
# 32556   40          3  154374         11              9   Married-civ-spouse
# 32557   58          3  151910         11              9              Widowed
# 32558   22          3  201490         11              9        Never-married
# 32559   52          4  287927         11              9   Married-civ-spouse
# 32561   39          8   77516          9             13        Never-married
#
# ...

# %%
adult["relationship"].replace([' Not-in-family','Not-in-family'],inplace=True)

# %%
adult["relationship"].unique()
# Out:
# array([' Husband', ' Wife', ' Own-child', ' Unmarried', ' Other-relative'],
#       dtype=object)

# %%
adult["relationship"]=enc.fit_transform(adult["relationship"])

# %%
adult
# Out:
#        age  workclass  fnlwgt  education  education_num       marital_status  \
# 0       50          5   83311          9             13   Married-civ-spouse
# 1       38          3  215646         11              9             Divorced
# 2       53          3  234721          1              7   Married-civ-spouse
# 3       28          3  338409          9             13   Married-civ-spouse
# 4       37          3  284582         12             14   Married-civ-spouse
# ...    ...        ...     ...        ...            ...                  ...
# 32556   40          3  154374         11              9   Married-civ-spouse
# 32557   58          3  151910         11              9              Widowed
# 32558   22          3  201490         11              9        Never-married
# 32559   52          4  287927         11              9   Married-civ-spouse
# 32561   39          8   77516          9             13        Never-married
#
# ...

# %%
adult["marital_status"].unique()
# Out:
# array([' Married-civ-spouse', ' Divorced', ' Married-spouse-absent',
#        ' Never-married', ' Separated', ' Married-AF-spouse', ' Widowed',
#        'Never-married'], dtype=object)

# %%
adult["marital_status"]=enc.fit_transform(adult["marital_status"])

# %%
adult
# Out:
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 0       50          5   83311          9             13               2
# 1       38          3  215646         11              9               0
# 2       53          3  234721          1              7               2
# 3       28          3  338409          9             13               2
# 4       37          3  284582         12             14               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   40          3  154374         11              9               2
# 32557   58          3  151910         11              9               6
# 32558   22          3  201490         11              9               4
# 32559   52          4  287927         11              9               2
# 32561   39          8   77516          9             13               7
#
#        occupation  relationship    race  sex  capital_gain  capital_loss  \
# ...

# %%
adult.drop(['capital_gain','capital_loss'],axis=1,inplace=True)

# %%
adult["race"].unique()
# Out:
# array(['White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
adult["race"].replace(['White',' Black',' Asian-Pac-Islander',' Amer-Indian-Eskimo',' Other'],[1,2,3,4,5],inplace=True)

# %%
adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32561 entries, 0 to 32561
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  int32
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  int32
#  4   occupation      32561 non-null  int32
#  5   race            32561 non-null  int64
#  6   sex             32561 non-null  int64
#  7   hours_per_week  32561 non-null  int64
#  8   native_country  32561 non-null  int32
#  9   income          32561 non-null  int64
# dtypes: int32(4), int64(6)
# memory usage: 2.2 MB

# %%
adult
# Out:
#        age  workclass  fnlwgt  education  occupation  race  sex  \
# 0       50          5   83311          9           3     1    0
# 1       38          3  215646         11           5     1    0
# 2       53          3  234721          1           5     2    0
# 3       28          3  338409          9           9     2    1
# 4       37          3  284582         12           3     1    1
# ...    ...        ...     ...        ...         ...   ...  ...
# 32556   40          3  154374         11           6     1    1
# 32557   58          3  151910         11           0     1    1
# 32558   22          3  201490         11           0     1    1
# 32559   52          4  287927         11           3     1    1
# 32561   39          8   77516          9          14     1    1
#
#        hours_per_week  native_country  income
# 0                  13              41       0
# 1                  40              41       0
# 2                  40              41       0
# ...

# %%
adult["income"].replace(' <=50K','<=50K',inplace=True)

# %%
adult["income"].replace(['<=50K', ' >50K'],[0,1],inplace=True)

# %%
adult
# Out:
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 0       50          5   83311          9             13               2
# 1       38          3  215646         11              9               0
# 2       53          3  234721          1              7               2
# 3       28          3  338409          9             13               2
# 4       37          3  284582         12             14               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   40          3  154374         11              9               2
# 32557   58          3  151910         11              9               6
# 32558   22          3  201490         11              9               4
# 32559   52          4  287927         11              9               2
# 32561   39          8   77516          9             13               7
#
#        occupation  relationship    race  sex  hours_per_week  native_country  \
# ...

# %%
x=adult.drop("income",axis=1)

# %%
y=adult["income"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=90)

# %%
#adult.drop(['education_num','marital_status','relationship'],axis=1,inplace=True)............Already done

# %%
adult

# %%
from sklearn.linear_model import LogisticRegression

# %%
model3=LogisticRegression()

# %%
model3.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model3.score(x_test,y_test)
# Out:
# 0.7581759557807461

# %%
model3.score(x_train,y_train)
# Out:
# 0.7594441031941032

# %% [markdown]
# #        here we got the 75.60% acuuracy of LogisticRegression on training dataset and 75.27% on testing dataset
